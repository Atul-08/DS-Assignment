# %% [markdown]
# # Pandas assognment 2[A]

# %%
# import necessary liberaries

# %%
import pandas as pd

# %%
# load the data set

# %%
df = pd .read_excel("Pandas_Assignment_2A[1].xlsx")

# %%
baby_names=

# %%
# first 10 entries

# %%
baby_names.head(10)
# Out:
#    Unnamed: 0     Id      Name  Year Gender State  Count
# 0       11349  11350      Emma  2004      F    AK     62
# 1       11350  11351   Madison  2004      F    AK     48
# 2       11351  11352    Hannah  2004      F    AK     46
# 3       11352  11353     Grace  2004      F    AK     44
# 4       11353  11354     Emily  2004      F    AK     41
# 5       11354  11355   Abigail  2004      F    AK     37
# 6       11355  11356    Olivia  2004      F    AK     33
# 7       11356  11357  Isabella  2004      F    AK     30
# 8       11357  11358    Alyssa  2004      F    AK     29
# 9       11358  11359    Sophia  2004      F    AK     28

# %%
# drop column unnamed:0 and id 
baby_names = baby_names.drop([ 'Unnamed: 0' ,'Id'], axis = 1)

# %%
baby_names
# Out:
#             Name  Year Gender State  Count
# 0           Emma  2004      F    AK     62
# 1        Madison  2004      F    AK     48
# 2         Hannah  2004      F    AK     46
# 3          Grace  2004      F    AK     44
# 4          Emily  2004      F    AK     41
# ...          ...   ...    ...   ...    ...
# 1016390     Seth  2014      M    WY      5
# 1016391  Spencer  2014      M    WY      5
# 1016392     Tyce  2014      M    WY      5
# 1016393   Victor  2014      M    WY      5
# 1016394   Waylon  2014      M    WY      5
#
# [1016395 rows x 5 columns]

# %%
baby_names['Gender'].value_counts()
# Out:
# Gender
# F    558846
# M    457549
# Name: count, dtype: int64

# %%
# group the data by name and assign to nams

# %%
names = baby_names.groupby('Name').sum()

# %%
names
# Out:
#            Year                                             Gender  \
# Name
# True      54274                        FFFFFFMMMMMMMMFFFFFFMMMMMMM
# Aaban      4027                                                 MM
# Aadan      8039                                               MMMM
# Aadarsh    2009                                                  M
# Aaden    393963  MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM...
# ...         ...                                                ...
# Zyra      14085                                            FFFFFFF
# Zyrah      4024                                                 FF
# Zyren      2013                                                  M
# Zyria     20089                                         FFFFFFFFFF
# Zyriah    18087                                          FFFFFFFFF
#
#                                                      State  Count
# Name
# True     CACACACACACACACACACACACACACAGAMDOHPATXTXTXTXTX...    157
# ...

# %%
# How many different names exist in the dataset?

# %%
names.drop(['Year' , 'Count'] , axis=1)
# Out:
#                                                     Gender  \
# Name
# True                           FFFFFFMMMMMMMMFFFFFFMMMMMMM
# Aaban                                                   MM
# Aadan                                                 MMMM
# Aadarsh                                                  M
# Aaden    MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM...
# ...                                                    ...
# Zyra                                               FFFFFFF
# Zyrah                                                   FF
# Zyren                                                    M
# Zyria                                           FFFFFFFFFF
# Zyriah                                           FFFFFFFFF
#
#                                                      State
# Name
# True     CACACACACACACACACACACACACACAGAMDOHPATXTXTXTXTX...
# Aaban                                                 NYNY
# Aadan                                             CACACATX
# ...

# %%
 # What is the name with most occurrences?

# %%
baby_names.groupby('Name').Count.sum().sort_values(ascending = False)
# Out:
# Name
# Jacob       242874
# Emma        214852
# Michael     214405
# Ethan       209277
# Isabella    204798
#              ...
# Raylena          5
# Breland          5
# Inari            5
# Brek             5
# Brevyn           5
# Name: Count, Length: 17632, dtype: int64

# %% [markdown]
# <!-- Done -->
